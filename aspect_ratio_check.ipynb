# %%
import pandas as pd
import numpy as np 

df = pd.read_csv('kimlik_labels_sadece_kimlik.csv')
df.head()
# Out:
#           frame   cx   cy    w    h  angle   class
# 0   kimlik1.jpg  145  170  288  261      0  kimlik
# 1  kimlik10.jpg  150  157  172  238      2  kimlik
# 2  kimlik11.jpg  150  151  300  295      0  kimlik
# 3  kimlik12.jpg  150  150  299  298      0  kimlik
# 4  kimlik13.jpg  146  152  266  284      0  kimlik

# %%
df1 = pd.DataFrame(df['w']/df['h'])
df1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)
